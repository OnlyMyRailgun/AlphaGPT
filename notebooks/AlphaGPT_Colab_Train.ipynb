# %% [markdown]
# # AlphaGPT Colab Training
#
# This notebook trains `AlphaGPT` against your cloud PostgreSQL database using the `birdeye` source.

# %% [markdown]
# ## 1. Clone the repository and install dependencies

# %%
# !git clone https://github.com/OnlyMyRailgun/AlphaGPT.git
# %cd /content/AlphaGPT
# !pip install -U pip
# !pip install torch pandas sqlalchemy psycopg2-binary tqdm loguru python-dotenv asyncpg

# %% [markdown]
# ## 2. Configure your cloud database
#
# Paste your cloud PostgreSQL connection URL below.

# %%
import os

# Example:
# os.environ['CLOUD_DB_URL'] = 'postgresql://user:password@host:5432/postgres?sslmode=require'
os.environ['CLOUD_DB_URL'] = ''

import sys

for name in [
    "model_core.config",
    "model_core.data_loader",
    "model_core.engine",
]:
    sys.modules.pop(name, None)

# %% [markdown]
# ## 3. Run training

# %%
# %run /content/AlphaGPT/notebooks/colab_birdeye_train.py

# %% [markdown]
# ## 4. Download outputs
#
# After training finishes, download the generated artifacts if needed.

# %%
from google.colab import files

# files.download('best_meme_strategy.json')
# files.download('training_history.json')
